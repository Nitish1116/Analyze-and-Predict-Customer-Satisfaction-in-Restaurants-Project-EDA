# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/Users/nitishkumar/Downloads/Data_sets/restaurant_customer_satisfaction.csv")

# %%
data
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# ...

# %%
data.head()
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly     27.829142
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
# 3           Indian       Lunch          1    Celebration   Dine-in
# 4          Chinese   Breakfast          1       Business  Takeaway
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# ...

# %%
data.tail()
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1495         American       Lunch          2       Business   Dine-in
# 1496          Italian       Lunch          4         Casual  Takeaway
# 1497         American       Lunch          4         Casual   Dine-in
# 1498          Italian      Dinner          6         Casual   Dine-in
# 1499          Chinese   Breakfast          4         Casual   Dine-in
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# ...

# %%
#No. of rows and columns 
data.shape
# Out:
# (1500, 19)

# %%
data.shape[0]
# Out:
# 1500

# %%
data.shape[1]
# Out:
# 19

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            1500 non-null   int64
#  1   Age                   1500 non-null   int64
#  2   Gender                1500 non-null   object
#  3   Income                1500 non-null   int64
#  4   VisitFrequency        1500 non-null   object
#  5   AverageSpend          1500 non-null   float64
#  6   PreferredCuisine      1500 non-null   object
#  7   TimeOfVisit           1500 non-null   object
#  8   GroupSize             1500 non-null   int64
#  9   DiningOccasion        1500 non-null   object
#  10  MealType              1500 non-null   object
#  11  OnlineReservation     1500 non-null   int64
#  12  DeliveryOrder         1500 non-null   int64
#  13  LoyaltyProgramMember  1500 non-null   int64
#  14  WaitTime              1500 non-null   float64
# ...

# %%
# statistical description of numeric columns
data.describe()
# Out:
#         CustomerID          Age         Income  AverageSpend    GroupSize  \
# count  1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean   1403.500000    43.832000   85921.890000    105.659004     5.035333
# std     433.157015    14.967157   38183.051749     52.381849     2.558864
# min     654.000000    18.000000   20012.000000     10.306127     1.000000
# 25%    1028.750000    31.750000   52444.000000     62.287907     3.000000
# 50%    1403.500000    44.000000   85811.000000    104.626408     5.000000
# 75%    1778.250000    57.000000  119159.250000    148.649330     7.000000
# max    2153.000000    69.000000  149875.000000    199.973527     9.000000
#
#        OnlineReservation  DeliveryOrder  LoyaltyProgramMember     WaitTime  \
# count        1500.000000    1500.000000           1500.000000  1500.000000
# mean            0.296667       0.405333              0.480000    30.163550
# std             0.456941       0.491120              0.499766    17.214184
# ...

# %%
#to find null values
data.isnull().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# Income                  0
# VisitFrequency          0
# AverageSpend            0
# PreferredCuisine        0
# TimeOfVisit             0
# GroupSize               0
# DiningOccasion          0
# MealType                0
# OnlineReservation       0
# DeliveryOrder           0
# LoyaltyProgramMember    0
# WaitTime                0
# ServiceRating           0
# FoodRating              0
# AmbianceRating          0
# HighSatisfaction        0
# dtype: int64

# %%
data.isnull().head(10)
# Out:
#    CustomerID    Age  Gender  Income  VisitFrequency  AverageSpend  \
# 0       False  False   False   False           False         False
# 1       False  False   False   False           False         False
# 2       False  False   False   False           False         False
# 3       False  False   False   False           False         False
# 4       False  False   False   False           False         False
# 5       False  False   False   False           False         False
# 6       False  False   False   False           False         False
# 7       False  False   False   False           False         False
# 8       False  False   False   False           False         False
# 9       False  False   False   False           False         False
#
#    PreferredCuisine  TimeOfVisit  GroupSize  DiningOccasion  MealType  \
# 0             False        False      False           False     False
# 1             False        False      False           False     False
# ...

# %%
#only columns
data.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Income', 'VisitFrequency',
#        'AverageSpend', 'PreferredCuisine', 'TimeOfVisit', 'GroupSize',
#        'DiningOccasion', 'MealType', 'OnlineReservation', 'DeliveryOrder',
#        'LoyaltyProgramMember', 'WaitTime', 'ServiceRating', 'FoodRating',
#        'AmbianceRating', 'HighSatisfaction'],
#       dtype='object')

# %%
# count
data['PreferredCuisine'].value_counts()
# Out:
# PreferredCuisine
# Italian     325
# Chinese     310
# Mexican     299
# Indian      296
# American    270
# Name: count, dtype: int64

# %%
# only specific row
data[data.index == 1]
# Out:
#    CustomerID  Age Gender  Income VisitFrequency  AverageSpend  \
# 1         655   19   Male   43623         Rarely    115.408622
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion MealType  \
# 1         American      Dinner          1         Casual  Dine-in
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 1                  0              0                     0  57.524294
#
#    ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 1              5           5               3                 0

# %%
#Isolating two or more rows using [ ] 
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.
data[data.index.isin(range(2,9))]
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
# 5         659   42  Female   28860        Monthly    111.064696
# 6         660   20  Female  131104         Weekly    120.236707
# 7         661   51  Female  137882         Weekly    160.979098
# 8         662   27    Male  149638         Weekly     56.558632
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 2         American      Dinner          6    Celebration   Dine-in
# 3           Indian       Lunch          1    Celebration   Dine-in
# 4          Chinese   Breakfast          1       Business  Takeaway
# 5          Chinese      Dinner          8    Celebration  Takeaway
# 6           Indian       Lunch          6       Business   Dine-in
# ...

# %%
data.loc[2:10]
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 2          656   41  Female   83737         Weekly    106.693771
# 3          657   43    Male   96768         Rarely     43.508508
# 4          658   55  Female   67937        Monthly    148.084627
# 5          659   42  Female   28860        Monthly    111.064696
# 6          660   20  Female  131104         Weekly    120.236707
# 7          661   51  Female  137882         Weekly    160.979098
# 8          662   27    Male  149638         Weekly     56.558632
# 9          663   32  Female  136145         Weekly     65.753455
# 10         664   21    Male   79249        Monthly     39.235383
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 2          American      Dinner          6    Celebration   Dine-in
# 3            Indian       Lunch          1    Celebration   Dine-in
# 4           Chinese   Breakfast          1       Business  Takeaway
# ...

# %%
#top 10 foodrating
data.nlargest(10,'FoodRating')
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0          654   35    Male   83380         Weekly     27.829142
# 1          655   19    Male   43623         Rarely    115.408622
# 3          657   43    Male   96768         Rarely     43.508508
# 5          659   42  Female   28860        Monthly    111.064696
# 16         670   59  Female  123325         Weekly     63.939240
# 31         685   18  Female   25148         Weekly    173.872310
# 40         694   67    Male   70219        Monthly    114.852870
# 44         698   50  Female  123950         Rarely    190.027105
# 56         710   19  Female   81440         Rarely     79.742895
# 63         717   21    Male   94550        Monthly     82.685349
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0           Chinese   Breakfast          3       Business  Takeaway
# 1          American      Dinner          1         Casual   Dine-in
# ...

# %%
# top food rating
data.loc[data['FoodRating'].idxmax()]
# Out:
# CustomerID                    654
# Age                            35
# Gender                       Male
# Income                      83380
# VisitFrequency             Weekly
# AverageSpend            27.829142
# PreferredCuisine          Chinese
# TimeOfVisit             Breakfast
# GroupSize                       3
# DiningOccasion           Business
# MealType                 Takeaway
# OnlineReservation               0
# DeliveryOrder                   1
# LoyaltyProgramMember            1
# WaitTime                43.523929
# ServiceRating                   2
# FoodRating                      5
# AmbianceRating                  4
# HighSatisfaction                0
# Name: 0, dtype: object

# %%
#least 10 foodrating
data.nsmallest(10,'AmbianceRating')
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 3          657   43    Male   96768         Rarely     43.508508
# 6          660   20  Female  131104         Weekly    120.236707
# 9          663   32  Female  136145         Weekly     65.753455
# 19         673   58    Male   70458         Rarely    197.370534
# 25         679   40  Female   38099         Weekly    118.814236
# 27         681   68    Male   82470         Weekly    146.452729
# 30         684   68  Female   87140         Weekly    140.890006
# 37         691   50  Female   52640        Monthly    113.686739
# 40         694   67    Male   70219        Monthly    114.852870
# 54         708   36  Female  149655        Monthly     64.443562
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 3            Indian       Lunch          1    Celebration   Dine-in
# 6            Indian       Lunch          6       Business   Dine-in
# ...

# %%
# to find mean value
mean_value=data['AverageSpend'].mean()
print(mean_value)
# Out:
# 105.65900359407259

# %%
# to find median value
median_value=data['AverageSpend'].median()
print(median_value)
# Out:
# 104.62640814349791

# %%
# to find mode value
mode_value=data['AverageSpend'].mode()[0]
print(mode_value)
# Out:
# 10.306126713600484

# %% [markdown]
# # Data Visualization

# %%
data.head()
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly     27.829142
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
# 3           Indian       Lunch          1    Celebration   Dine-in
# 4          Chinese   Breakfast          1       Business  Takeaway
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# ...

# %%
#Correlation between Income and Average Spend
plt.figure(figsize=(10, 6))
sns.histplot(data,x='Income', y='AverageSpend', hue='HighSatisfaction', palette='coolwarm')
plt.title('Income vs Average Spend')
plt.xlabel('Income Rs')
plt.ylabel('Average Spend Rs')
plt.show()

# %%
#Count of Customers by Preferred Cuisine
plt.figure(figsize=(10, 6))
sns.countplot(data,x='PreferredCuisine',hue='PreferredCuisine', palette='Set2')
plt.title('Count of Customers by Preferred Cuisine')
plt.show()

# %%
#Distribution of Service Ratings
plt.figure(figsize=(10, 6))
sns.histplot(data['ServiceRating'], bins=5, kde=True, color='green')
plt.title('Distribution of Service Ratings')
plt.show()

# %%
#Relationship between Wait Time and Service Rating
plt.figure(figsize=(10, 6))
sns.lineplot(data,x='WaitTime', y='ServiceRating', marker='o', hue='HighSatisfaction', palette='muted')
plt.title('Wait Time vs Service Rating')
plt.xlabel('Wait Time')
plt.ylabel('Service Rating')
plt.grid(True)
plt.show()

# %%
#Gender-based Average Spendings
plt.figure(figsize=(10, 6))
sns.boxplot(data,x='Gender', y='AverageSpend',hue= 'Gender',legend=False,palette='Blues')
plt.title('Gender-wise Average Spendings')
plt.show()

# %%
#Correlation Heatmap
plt.figure(figsize=(10, 6))
correlation = data[['Age', 'Income', 'AverageSpend', 'GroupSize', 'WaitTime', 'ServiceRating', 'FoodRating', 'AmbianceRating']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
#Customer Count by Visit Frequency
plt.figure(figsize=(10, 6))
sns.countplot(data,x='VisitFrequency',hue='VisitFrequency', palette='Blues')
plt.title('Customer Count by Visit Frequency')
plt.xlabel('Visit Frequency')
plt.ylabel('Count')
plt.show()

# %%
#Service Rating Distribution by Meal Type
plt.figure(figsize=(10, 6))
sns.violinplot(data,x='MealType', y='ServiceRating',hue='MealType', palette='Set1')
plt.title('Service Rating Distribution by Meal Type')
plt.xlabel('Meal Type')
plt.ylabel('Service Rating')
plt.show()

# %%
#Average Spend by Dining Occasion
plt.figure(figsize=(10, 6))
sns.barplot(data,x='DiningOccasion', y='AverageSpend',hue='DiningOccasion', palette='Set3')
plt.title('Average Spend by Dining Occasion')
plt.xlabel('Dining Occasion')
plt.ylabel('Average Spend Rs')
plt.show()

# %%
#Distribution of Food Ratings
plt.figure(figsize=(10, 6))
sns.histplot(data['FoodRating'], bins=5, kde=True, color='purple')
plt.title('Distribution of Food Ratings')
plt.xlabel('Food Rating')
plt.ylabel('Count')
plt.show()

# %%
#Group Size vs. Wait Time
plt.figure(figsize=(10, 6))
sns.scatterplot(data,x='GroupSize', y='WaitTime', hue='HighSatisfaction', palette='coolwarm', s=100)#s=100: This sets the size of the points to 100, making the points larger for better visibility.
plt.title('Group Size vs. Wait Time')
plt.xlabel('Group Size')
plt.ylabel('Wait Time (Minutes)')
plt.grid(True)
plt.show()

# %%
#Average Spend by Time of Visit
plt.figure(figsize=(10, 6))
sns.barplot(data,x='TimeOfVisit', y='AverageSpend',hue= 'TimeOfVisit',palette='muted')
plt.title('Average Spend by Time of Visit')
plt.xlabel('Time of Visit')
plt.ylabel('Average Spend Rs')
plt.show()

# %%
#Average Spend by Preferred Cuisine
plt.figure(figsize=(10, 6))
sns.barplot(data,x='PreferredCuisine', y='AverageSpend',hue='PreferredCuisine', palette='Set2')
plt.title('Average Spend by Preferred Cuisine')
plt.xlabel('Preferred Cuisine')
plt.ylabel('Average Spend Rs')
plt.xticks(rotation=45)
plt.show()

# %%
#Service Rating by High Satisfaction
plt.figure(figsize=(10, 6))
sns.boxplot(data,x='HighSatisfaction', y='ServiceRating',hue='HighSatisfaction', palette='Set1')
plt.title('Service Rating by High Satisfaction')
plt.xlabel('High Satisfaction')
plt.ylabel('Service Rating')
plt.show()

# %%
#Wait Time by Dining Occasion
plt.figure(figsize=(10, 6))
sns.boxplot(data,x='DiningOccasion', y='WaitTime',hue='DiningOccasion', palette='Set3')
plt.title('Wait Time by Dining Occasion')
plt.xlabel('Dining Occasion')
plt.ylabel('Wait Time (Minutes)')
plt.xticks(rotation=45)
plt.show()

# %%
#Income vs. Food Rating
plt.figure(figsize=(10, 6))
sns.scatterplot(data,x='Income', y='FoodRating', hue='HighSatisfaction', palette='coolwarm', s=100)
plt.title('Income vs. Food Rating')
plt.xlabel('Income Rs')
plt.ylabel('Food Rating')
plt.grid(True)
plt.show()

# %%
#Customer Count by Loyalty Program Membership
plt.figure(figsize=(10, 6))
sns.countplot(data,x='LoyaltyProgramMember',hue='LoyaltyProgramMember', palette='pastel')
plt.title('Customer Count by Loyalty Program Membership')
plt.xlabel('Loyalty Program Member')
plt.ylabel('Count')
plt.show()

# %%
#Average Spend by Meal Type
plt.figure(figsize=(10, 6))
sns.barplot(data,x='MealType', y='AverageSpend',hue='MealType', palette='Set2')
plt.title('Average Spend by Meal Type')
plt.xlabel('Meal Type')
plt.ylabel('Average Spend Rs')
plt.show()

# %%
#Service Rating vs. Ambiance Rating
plt.figure(figsize=(10, 6))
sns.scatterplot(data,x='ServiceRating', y='AmbianceRating', hue='HighSatisfaction', palette='coolwarm', s=100)
plt.title('Service Rating vs. Ambiance Rating')
plt.xlabel('Service Rating')
plt.ylabel('Ambiance Rating')
plt.grid(True)
plt.show()

# %%
#Preferred Cuisine by Gender
plt.figure(figsize=(10, 6))
sns.countplot(data,x='PreferredCuisine', hue='Gender', palette='Set1')
plt.title('Preferred Cuisine by Gender')
plt.xlabel('Preferred Cuisine')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
#Average Spend vs. Age
plt.figure(figsize=(10, 6))
sns.lineplot(data,x='Age', y='AverageSpend', marker='o', hue='HighSatisfaction', palette='coolwarm')
plt.title('Average Spend vs. Age')
plt.xlabel('Age')
plt.ylabel('Average Spend Rs')
plt.grid(True)
plt.show()
